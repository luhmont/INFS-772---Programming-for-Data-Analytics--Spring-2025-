# %% [markdown]
# # Introduction to Notebook
#
# ## Spring 2022 Week 2
#
#
# ## Introduction

# %%
import pandas as pd 
pd.__version__
# Out:
# '1.2.0'

# %% [markdown]
# | |Col1 | Col2  |
# |---|------|------|
# |Row1  |   10    | 20|
# |Row2|   30    | 40|

# %% [markdown]
# ## Triple backticks for code blocks

# %% [markdown]
# ```python
# print("Hello World")
# ```

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Multimedia

# %% [markdown]
# <img src="https://www.python.org/static/img/python-logo@2x.png" width="320" height="240">

# %%
import sklearn as sk
sk.__version__
# Out:
# '0.23.2'

# %%
myweek1data = np.array([['','Col1','Col2'],
                ['Row1',10,20],
                ['Row2',30,40]])
mydf = pd.DataFrame(data=myweek1data[1:,1:],
    index=myweek1data[1:,0],
    columns=myweek1data[0,1:])

mydf
                           
# print(pd.DataFrame(data=data[1:,1:],
#                  index=data[1:,0],
 #                 columns=data[0,1:]))
# Out:
#      Col1 Col2
# Row1   10   20
# Row2   30   40

# %%
np.sqrt(1024)
# Out:
# 32.0

# %%
data = np.array([['','Col1','Col2'],
                ['Row1',1,2],
                ['Row2',3,4]])
                
print(pd.DataFrame(data=data[1:,1:],
                  index=data[1:,0],
                  columns=data[0,1:]))
# Out:
#      Col1 Col2
# Row1    1    2
# Row2    3    4

# %% [markdown]
# ## LaTex equations
#
# ### IPython notebook uses MathJax to render LaTeX inside html/markdown. Just put your LaTeX math inside the dollar sign.
# $ c = \sqrt{a^2 + b^2}$

# %% [markdown]
# ## Markdown Cells

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# * ONE
# * TWO
# * THREE
#
# ** Bold text here! **
#
# *italics*
#
# http://google.com
#
# http://www.dsu.edu

# %%
# %matplotlib inline
from matplotlib.pyplot import plot
plot([0,1,0,1])

# %% [markdown]
# %matplotlib inline sets the backend of matplotlib to the 'inline' backend:
#
# With this backend, the output of plotting commands is displayed inline within frontends like the Jupyter notebook, directly below the code cell that produced it. The resulting plots will then also be stored in the notebook document.
#
# Now let's try %matplotlib notebook for interactive plotting

# %%
# %matplotlib notebook
from matplotlib.pyplot import plot
plot([0,1,0,1])
# Out:
# <img src="data:image/png;base64,..." width="325.6">

# %% [markdown]
# ## Code Samples with Snippets
